# %%
import pandas as pd

# %%
data = {
    "Src Port": [80, 53, 22, 443, 21, 53, 80, 443],
    "Dst Port": [443, 1024, 5000, 80, 5001, 2048, 3000, 8000],
    "Protocol": ["TCP", "UDP", "TCP", "TCP", "TCP", "UDP", "TCP", "TCP"],
    "Packet Size": [500, 100, 800, 450, 1200, 90, 950, 600],
    "Attack Type": ["Normal", "Normal", "Attack", "Normal", "Attack", "Normal", "Attack", "Normal"]
}

# %%
df = pd.DataFrame(data)

# %%
print(df)
# Out:
#    Src Port  Dst Port Protocol  Packet Size Attack Type
# 0        80       443      TCP          500      Normal
# 1        53      1024      UDP          100      Normal
# 2        22      5000      TCP          800      Attack
# 3       443        80      TCP          450      Normal
# 4        21      5001      TCP         1200      Attack
# 5        53      2048      UDP           90      Normal
# 6        80      3000      TCP          950      Attack
# 7       443      8000      TCP          600      Normal

# %%
from sklearn.preprocessing import LabelEncoder
protocol_encoder = LabelEncoder()
df["Protocol"] = protocol_encoder.fit_transform(df["Protocol"])

# %%
df
# Out:
#    Src Port  Dst Port  Protocol  Packet Size Attack Type
# 0        80       443         0          500      Normal
# 1        53      1024         1          100      Normal
# 2        22      5000         0          800      Attack
# 3       443        80         0          450      Normal
# 4        21      5001         0         1200      Attack
# 5        53      2048         1           90      Normal
# 6        80      3000         0          950      Attack
# 7       443      8000         0          600      Normal

# %%
attackType_encoder = LabelEncoder()
df["Attack Type"] = attackType_encoder.fit_transform(df["Attack Type"])

# %%
df
# Out:
#    Src Port  Dst Port  Protocol  Packet Size  Attack Type
# 0        80       443         0          500            1
# 1        53      1024         1          100            1
# 2        22      5000         0          800            0
# 3       443        80         0          450            1
# 4        21      5001         0         1200            0
# 5        53      2048         1           90            1
# 6        80      3000         0          950            0
# 7       443      8000         0          600            1

# %%
from sklearn.model_selection import train_test_split
x = df.drop(columns=["Attack Type"])
y = df["Attack Type"]

# %%
x
# Out:
#    Src Port  Dst Port  Protocol  Packet Size
# 0        80       443         0          500
# 1        53      1024         1          100
# 2        22      5000         0          800
# 3       443        80         0          450
# 4        21      5001         0         1200
# 5        53      2048         1           90
# 6        80      3000         0          950
# 7       443      8000         0          600

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
print(f"Training samples: {len(x_train)}\nTesting samples: {len(x_test)}")
# Out:
# Training samples: 6
# Testing samples: 2

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()
model.fit(x_train, y_train)
print('Model trainig completed!')
# Out:
# Model trainig completed!

# %%
y_predict = model.predict(x_test)
print('Predictions: ',y_predict.tolist())
print('Actual results: ',y_test.tolist())
# Out:
# Predictions:  [1, 1]
# Actual results:  [1, 1]

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test, y_predict)
print(f'Model accuracy: {(accuracy*100):.2f}')
# Out:
# Model accuracy: 100.00
